# %% [markdown]
# # IMPORTING and READING DATA FROM CSV FILE

# %%
import csv
filename = "device_features.csv"

print (f"{file_name} is now open for read")
# Out:
# device_features.csv is now open for read

# %% [markdown]
# # RETRIEVING THE BRAND,MODEL,RAM_CAPACITY,MARKET_REGIONS AND INO ADDED USING A SPECIFIED CODENAME.

# %%
#importing and reading from csv file

import csv
from tabulate import tabulate

# define a file name
file_name = "device_features.csv"

# Open the file and read its contents
try:
    with open(file_name, encoding='UTF-8') as csv_file:
        print(f"{file_name} is now open for read")
        
        # read from the csv file
        csv_reader = csv.reader(csv_file)
        
        # accept input from the user - oem_id
        oem_id = input("please enter the oem_id")
        
        result = []
        # Display rows where user input matches oem_id
        for row in csv_reader:
            if oem_id.lower() == row[0].lower():
                result.append({ 
                    "Brand": row[1],
                    "Model": row[2],
                    "Manufacture": row[6],
                    "Price": row[15],
                    "Price_currency": row[16]
                })       
        # Print the result in a tabular format
        print(tabulate(result, headers="keys", tablefmt="pretty"))
        
except IOError:
    print("Cannot read file.")

# %%
import csv
import pandas as pd

file_name = "device_features.csv"
result = []

try:
    with open(file_name, encoding='UTF-8') as csv_file:
        print(f"{file_name} is now open for read")        
        csv_reader = csv.reader(csv_file)
        Codename = input("please enter the code name")
        for row in csv_reader:
            if row[7] == Codename:
                result.append({ 
                    "Brand": row[1],
                    "Model": row[2],
                    "Ram_capacity": row[23],
                    "market_regions": row[44],
                    "info_added_date": row[45]
                })

        if result:
            df = pd.DataFrame(result)
            print(df)
        else:
            print("No matching device found for the given code name.")

except IOError:
    print("Cannot read file.")

# %%
import csv
import pandas as pd
from tabulate import tabulate

file_name = "device_features.csv"

def retrieve_device_info_by_ram_capacity(ram_capacity):
    try:
        with open(file_name, encoding='UTF-8') as csv_file:
            print(f"{file_name} is now open for read")
            
            csv_reader = csv.reader(csv_file)
            
            # Initialize a list to store matching devices
            matching_devices = []
            
            for row in csv_reader:
                # Check if the row has data and matches the RAM capacity
                if len(row) > 0 and row[23].lower() == ram_capacity.lower():
                    device_info = {
                        "oem_id": row[10],          # Retrieve oem_id
                        "release_date": row[46],    # Retrieve release date
                        "announcement_date": row[47], # Retrieve announcement date
                        "dimensions": row[25],     # Retrieve dimensions
                        "device_category": row[5]  # Retrieve device category
                    }
                    matching_devices.append(device_info)
            
            if matching_devices:
                # Convert the list of dictionaries to a DataFrame
                df = pd.DataFrame(matching_devices)
                # Display the DataFrame in tabular form
                print(tabulate(df, headers='keys', tablefmt='pretty'))
            else:
                print("No devices found with RAM capacity", ram_capacity)
        
    except IOError:
        print("Cannot read file.")

# Prompt user for RAM capacity input
ram_capacity_input = input("Please enter the RAM capacity: ")

# Call the function to retrieve device information based on RAM capacity
retrieve_device_info_by_ram_capacity(ram_capacity_input)

# %% [markdown]
# #  RETREIVING INFORMATION USING THE DEVICE CPU CAPACITY

# %%
import csv

file_name = "device_features.csv"

def retrieve_device_info_by_cpu(cpu_model):
    try:
        with open(file_name, encoding='UTF-8') as csv_file:
            print(f"{file_name} is now open for read")
            
            csv_reader = csv.reader(csv_file)
            
            matching_devices = []
            
            for row in csv_reader:
                if len(row) > 0 and cpu_model.lower() in row[22].lower():
                    device_info = {
                        "Model Name": row[2],       # Retrieve model name
                        "CPU": row[22],            # Retrieve CPU
                        "Platform": row[16],       # Retrieve platform
                        "RAM Type": row[21]        # Retrieve RAM type
                    }
                    matching_devices.append(device_info)
            
            if matching_devices:
                print(f"Devices with CPU model '{cpu_model}':")
                for device in matching_devices:
                    print(device)
            else:
                print(f"No devices found with CPU model '{cpu_model}'")
        
    except IOError:
        print("Cannot read file.")

# user prompt to enter the cpu model
cpu_model_input = input("Please enter the CPU model: ")

# Call the function to retrieve device information based on CPU model
retrieve_device_info_by_cpu(cpu_model_input)

# %%
import csv

file_name = "device_features.csv"

def retrieve_device_info_by_cpu(cpu_model):
    try:
        with open(file_name, encoding='UTF-8') as csv_file:
            print(f"{file_name} is now open for read")
            
            csv_reader = csv.reader(csv_file)
            
            matching_devices = []
            
            for index, row in enumerate(csv_reader):
                print(f"Processing row {index}: {row}")
                if len(row) > 22 and cpu_model.lower() in row[22].lower():
                    device_info = {
                        "Model Name": row[2],       # Retrieve model name
                        "CPU": row[22],            # Retrieve CPU
                        "Platform": row[16],       # Retrieve platform
                        "RAM Type": row[21]        # Retrieve RAM type
                    }
                    matching_devices.append(device_info)
            
            if matching_devices:
                print(f"Devices with CPU model '{cpu_model}':")
                for device in matching_devices:
                    print(device)
            else:
                print(f"No devices found with CPU model '{cpu_model}'")
        
    except IOError:
        print("Cannot read file.")

# user prompt to enter the cpu model
cpu_model_input = input("Please enter the CPU model: ")

# Call the function to retrieve device information based on CPU model
retrieve_device_info_by_cpu(cpu_model_input)

# %%
import csv
import pandas as pd

file_name = "device_features.csv"

def retrieve_device_info_by_cpu(cpu_model):
    matching_devices = []

    try:
        with open(file_name, encoding='UTF-8') as csv_file:
            print(f"{file_name} is now open for read")
            csv_reader = csv.reader(csv_file)
            
            for index, row in enumerate(csv_reader):
                print(f"Processing row {index}: {row}")
                if len(row) > 22 and cpu_model.lower() in row[22].lower():
                    device_info = {
                        "Model Name": row[2],       # Retrieve model name
                        "CPU": row[22],            # Retrieve CPU
                        "Platform": row[16],       # Retrieve platform
                        "RAM Type": row[21]        # Retrieve RAM type
                    }
                    matching_devices.append(device_info)
            
            if matching_devices:
                print(f"Devices with CPU model '{cpu_model}':")
                df = pd.DataFrame(matching_devices)
                print(df)
            else:
                print(f"No devices found with CPU model '{cpu_model}'")
        
    except IOError:
        print("Cannot read file.")

# user prompt to enter the cpu model
cpu_model_input = input("Please enter the CPU model: ")

# Call the function to retrieve device information based on CPU model
retrieve_device_info_by_cpu(cpu_model_input)

# %%
import csv
import pandas as pd

file_name = "device_features.csv"

def retrieve_device_info_by_cpu(cpu_model):
    matching_devices = []

    try:
        with open(file_name, encoding='UTF-8') as csv_file:
            print(f"{file_name} is now open for read")
            csv_reader = csv.reader(csv_file)
            
            for index, row in enumerate(csv_reader):
                if len(row) > 22 and cpu_model.lower() in row[22].lower():
                    device_info = {
                        "Model Name": row[2],       # Retrieve model name
                        "CPU": row[22],            # Retrieve CPU
                        "Platform": row[16],       # Retrieve platform
                        "RAM Type": row[21]        # Retrieve RAM type
                    }
                    matching_devices.append(device_info)
            
            if matching_devices:
                print(f"Devices with CPU model '{cpu_model}':")
                df = pd.DataFrame(matching_devices)
                print(df.to_string(index=False))  # Display DataFrame without index
            else:
                print(f"No devices found with CPU model '{cpu_model}'")
        
    except IOError:
        print("Cannot read file.")

# user prompt to enter the cpu model
cpu_model_input = input("Please enter the CPU model: ")

# Call the function to retrieve device information based on CPU model
retrieve_device_info_by_cpu(cpu_model_input)

# %% [markdown]
#                                      SECTION B

# %% [markdown]
# # USING PANDAS TO IDENTIFY THE TOP FIVE REGION IN THE CSV DATA

# %%
import pandas as pd

def top_regions_for_brand(file_name, brand_name):
    """
    Identify the top 5 regions where a specific brand of devices was sold.
    
    Args:
    - file_name: The file path of the CSV file containing device information.
    - brand_name: The brand name for which to identify top regions.
    
    Returns:
    - DataFrame: Top 5 regions where the specified brand's devices were sold.
    """
    # Read the CSV file into a DataFrame
    df_devices = pd.read_csv(file_name)
    
    # devices based on the provided brand name
    brand_devices = df_devices[df_devices['brand'].str.lower() == brand_name.lower()]
    
    # Count occurrences of regions for the specified brand
    top_regions = brand_devices['market_regions'].value_counts().head(5)
    
    return top_regions

# Define the file path for device information
file_name = "device_features.csv"

# Specify the brand name for analysis
brand_name = "Samsung"  # users can replace with any brand name 

# Retrieve top 5 regions for the specified brand
top_regions = top_regions_for_brand(file_name, brand_name)

# Display the top 5 regions
print(f"Top 5 regions where {brand_name} devices were sold:")
print(top_regions)

# %% [markdown]
# # AVERAGE PRICE OF A DEVICE USING SAMSUNG AS A SAMPLE

# %%
import pandas as pd

def average_price_for_brand(file_name, brand_name, target_currency):
    df_devices = pd.read_csv(file_name)
    
    # Filter devices based on the provided brand name
    brand_devices = df_devices[df_devices['brand'].str.lower() == brand_name.lower()].copy()
    # Using .copy() ensures that we work on a copy of the filtered data, preventing the SettingWithCopyWarning
    
    conversion_rates = {'USD': 1, 'EUR': 1.12, 'GBP': 1.31}  # Replace with actual rates
    
    # Convert prices to the target currency for analysis
    brand_devices.loc[:, 'price_in_target_currency'] = brand_devices.apply(
        lambda row: row['price'] * conversion_rates.get(row['price_currency'], 1), axis=1)
    # Using .loc to set values in the original DataFrame directly
    
    # Calculate the average price for the brand in the target currency
    average_price = brand_devices['price_in_target_currency'].mean()
    
    return average_price

# Define the file path for device information
file_name = "device_features.csv"

# Specify the brand name for analysis and the target currency
brand_name = "Samsung"  # Replace with your desired brand name
target_currency = "USD"  # Replace with your desired target currency code

# Calculate the average price for the specified brand in the target currency
avg_price = average_price_for_brand(file_name, brand_name, target_currency)

# Display the average price
print(f"Average price of {brand_name} devices in {target_currency}: ${avg_price:.2f}")

# %% [markdown]
# # TOP FIVE REGION WHICH A DEVICE IS SOLD ( SAMSUNG AS A CASE STUDY)

# %%
import pandas as pd
import matplotlib.pyplot as plt

def top_regions_for_brand(file_name, brand_name):
    """
    Identify the top 5 regions where a specific brand of devices was sold.
    
    Args:
    - file_name: The file path of the CSV file containing device information.
    - brand_name: The brand name for which to identify top regions.
    
    Returns:
    - DataFrame: Top 5 regions where the specified brand's devices were sold.
    """
    # Read the CSV file into a DataFrame
    df_devices = pd.read_csv(file_name)
    
    # devices based on the provided brand name
    brand_devices = df_devices[df_devices['brand'].str.lower() == brand_name.lower()]
    
    # Count occurrences of regions for the specified brand
    top_regions = brand_devices['market_regions'].value_counts().head(5)
    
    return top_regions

# Define the file path for device information
file_name = "device_features.csv"

# Specify the brand name for analysis
brand_name = "Samsung"  # users can replace with any brand name 

# Retrieve top 5 regions for the specified brand
top_regions = top_regions_for_brand(file_name, brand_name)

# Plotting the top 5 regions for the specified brand using a bar chart
plt.figure(figsize=(8, 5))
top_regions.plot(kind='bar', color='lightblue', edgecolor='black')
plt.title(f"Top 5 regions where {brand_name} devices were sold", fontsize=14)
plt.xlabel("Regions", fontsize=12)
plt.ylabel("Number of Devices Sold", fontsize=12)
plt.xticks(rotation=45, ha='right', fontsize=10)
plt.yticks(fontsize=10)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# # CALCULATIONS OF WEIGHT PER GRAM FOR ALL MANUFACTURERS

# %%
import pandas as pd

# Load data from the CSV file into a DataFrame
file_name = "device_features.csv"
df_devices = pd.read_csv(file_name)

# Calculate the average mass for each manufacturer
manufacturer_avg_mass = df_devices.groupby('manufacturer')['weight_gram'].mean().reset_index()

# Display the list of average masses for all manufacturers
print(manufacturer_avg_mass)

# %%
import pandas as pd
import matplotlib.pyplot as plt

def top_regions_for_brand(file_name, brand_name):
    """
    Identify the top 5 regions where a specific brand of devices was sold.
    
    Args:
    - file_name: The file path of the CSV file containing device information.
    - brand_name: The brand name for which to identify top regions.
    
    Returns:
    - DataFrame: Top 5 regions where the specified brand's devices were sold.
    """
    df_devices = pd.read_csv(file_name)
    brand_devices = df_devices[df_devices['brand'].str.lower() == brand_name.lower()]
    top_regions = brand_devices['market_regions'].value_counts().head(5)
    return top_regions

file_name = "device_features.csv"
brand_name = "Samsung"

top_regions = top_regions_for_brand(file_name, brand_name)

plt.figure(figsize=(6, 4))
top_regions.plot(kind='bar', color='skyblue', edgecolor='black')
plt.title(f"Top 5 regions where {brand_name} devices were sold", fontsize=12)
plt.xlabel("Regions", fontsize=10)
plt.ylabel("Number of Devices Sold", fontsize=10)
plt.xticks(rotation=45, ha='right', fontsize=8)
plt.yticks(fontsize=8)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
import pandas as pd

# Load data from the CSV file into a DataFrame
file_name = "device_features.csv"
df_devices = pd.read_csv(file_name)

# Calculate the average mass for each manufacturer specifically for samsung
manufacturer_avg_mass = df_devices.groupby('manufacturer')['weight_gram'].mean().reset_index()

# Display the list of average masses for all manufacturers
display(manufacturer_avg_mass)

# %% [markdown]
# # USING PIE CHART TO SHOW THE PERFORMANCE RAM TYPE IN THE MARKET

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load data from the CSV file into a DataFrame
file_name = "device_features.csv"
df_devices = pd.read_csv(file_name)

# Count occurrences of each RAM type
ram_counts = df_devices['ram_type'].value_counts()

# Plotting the proportion of RAM types using a pie chart
plt.figure(figsize=(6, 6))  # Adjust the figsize here
plt.pie(ram_counts, labels=ram_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Proportion of RAM Types for Devices')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %% [markdown]
# # USING PANDAS TO ASCERTAIN THE COLUMNS IN THE DATASET

# %% [markdown]
# # ASCERTAINING COLUMN NAMES FOR BETTER ANALYSIS

# %%
import pandas as pd
from tabulate import tabulate

# Load data from the CSV file into a DataFrame
file_name = "device_features.csv"
df_devices = pd.read_csv(file_name)

# Display the column names in a table format
print(tabulate(df_devices.columns.to_frame(), headers=['Column Names'], tablefmt='pretty'))

# %% [markdown]
# # NUMBER OF DEVICES IN USB CONNECTORS

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load data from the CSV file into a DataFrame
file_name = "device_features.csv"
df_devices = pd.read_csv(file_name)

# Count the number of devices for each USB connector type
usb_counts = df_devices['usb_connector'].value_counts()

# Plotting the number of devices for each USB connector type using a bar chart
plt.figure(figsize=(6, 4))
usb_counts.plot(kind='bar', color='skyblue')
plt.xlabel('USB Connector Type')
plt.ylabel('Number of Devices')
plt.title('Number of Devices for Each USB Connector Type')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load data from the CSV file into a DataFrame
file_name = "device_features.csv"
df_devices = pd.read_csv(file_name)

# Assuming 'released_date' is in datetime format
df_devices['released_date'] = pd.to_datetime(df_devices['released_date'])

# Filter data for the relevant years (2020-2023) and GBP currency
filtered_data = df_devices[(df_devices['released_date'].dt.year >= 2020) & 
                           (df_devices['released_date'].dt.year <= 2023) & 
                           (df_devices['price_currency'] == 'GBP')]

# Extract year-wise data and plot separate charts
for year in range(2020, 2024):
    year_data = filtered_data[filtered_data['released_date'].dt.year == year]
    if not year_data.empty:
        monthly_avg_prices = year_data.groupby(year_data['released_date'].dt.month)['price'].mean()
        plt.figure(figsize=(8, 6))
        plt.plot(monthly_avg_prices, marker='o')
        plt.title(f"Monthly Average Price Trends in {year} (GBP)")
        plt.xlabel('Month')
        plt.ylabel('Average Price (GBP)')
        plt.xticks(range(1, 13), ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
        plt.grid(True)
        plt.show()

# %% [markdown]
# # MONTHLY PRICE TRENDS IN GBP

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load data from the CSV file into a DataFrame
file_name = "device_features.csv"
df_devices = pd.read_csv(file_name)

# Assuming 'released_date' is in datetime format
df_devices['released_date'] = pd.to_datetime(df_devices['released_date'])

# Filter data for the relevant years (2020-2023) and GBP currency
filtered_data = df_devices[
    (df_devices['released_date'].dt.year >= 2020)
    & (df_devices['released_date'].dt.year <= 2023)
    & (df_devices['price_currency'] == 'GBP')
]

# Extract year-wise data and plot separate charts
for year in range(2020, 2024):
    year_data = filtered_data[filtered_data['released_date'].dt.year == year]
    if not year_data.empty:
        monthly_avg_prices = year_data.groupby(year_data['released_date'].dt.month)['price'].mean()
        plt.figure(figsize=(6, 4))  # Adjust the figsize for smaller visualizations
        plt.plot(monthly_avg_prices, marker='o')
        plt.title(f"Monthly Average Price Trends in {year} (GBP)")
        plt.xlabel('Month')
        plt.ylabel('Average Price (GBP)')
        plt.xticks(
            range(1, 13),
            ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'],
        )
        plt.grid(True)
        plt.show()

# %%
#

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load data from the CSV file into a DataFrame
file_name = "device_features.csv"
df_devices = pd.read_csv(file_name)

#'released_date' is in datetime format
df_devices['released_date'] = pd.to_datetime(df_devices['released_date'])

# Filter data for the relevant years (2020-2023) and GBP currency
filtered_data = df_devices[(df_devices['released_date'].dt.year >= 2020) & 
                           (df_devices['released_date'].dt.year <= 2023) & 
                           (df_devices['price_currency'] == 'GBP')]

# Set a custom color palette for the lines
colors = ['#FF5733', '#33FF7A', '#337AFF', '#FF33E9']

# Extract year-wise data and plot separate charts
for idx, year in enumerate(range(2020, 2024)):
    year_data = filtered_data[filtered_data['released_date'].dt.year == year]
    if not year_data.empty:
        monthly_avg_prices = year_data.groupby(year_data['released_date'].dt.month)['price'].mean()
        plt.figure(figsize=(6, 4))
        plt.plot(monthly_avg_prices, marker='o', color=colors[idx], linewidth=2)
        plt.title(f"Monthly Average Price Trends in {year} (GBP)", fontsize=8)
        plt.xlabel('Month', fontsize=12)
        plt.ylabel('Average Price (GBP)', fontsize=6)
        plt.xticks(range(1, 13), ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'], fontsize=10)
        plt.yticks(fontsize=10)
        plt.grid(True, linestyle='--', linewidth=0.5, alpha=0.7)
        plt.legend([f'{year}'], loc='upper left')
        plt.tight_layout()
        plt.show()

# %% [markdown]
#  # VISULISATION BASED ON YEARLY PERFORMANCE OF DEVICES BETWEEN 2020 AND 2024 USING GBP

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load data from the CSV file into a DataFrame
file_name = "device_features.csv"
df_devices = pd.read_csv(file_name)

# Assuming 'released_date' is in datetime format
df_devices['released_date'] = pd.to_datetime(df_devices['released_date'])

# Filter data for the relevant years (2020-2023) and GBP currency
filtered_data = df_devices[(df_devices['released_date'].dt.year >= 2020) & 
                           (df_devices['released_date'].dt.year <= 2023) & 
                           (df_devices['price_currency'] == 'GBP')]

# Set a custom color palette for the lines
colors = ['#FF5733', '#33FF7A', '#337AFF', '#FF33E9']

# Extract year-wise data and plot separate charts
for idx, year in enumerate(range(2020, 2024)):
    year_data = filtered_data[filtered_data['released_date'].dt.year == year]
    if not year_data.empty:
        monthly_avg_prices = year_data.groupby(year_data['released_date'].dt.month)['price'].mean()
        plt.figure(figsize=(6, 4))
        plt.plot(monthly_avg_prices, marker='o', color=colors[idx], linewidth=2)
        plt.title(f"Monthly Average Price Trends in {year} (GBP)", fontsize=14)
        plt.xlabel('Month', fontsize=10)
        plt.ylabel('Average Price (GBP)', fontsize=10)
        plt.xticks(range(1, 13), ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'], fontsize=8)
        plt.yticks(fontsize=8)
        plt.grid(True, linestyle='--', linewidth=0.5, alpha=0.7)
        plt.legend([f'{year}'], loc='upper left')
        plt.tight_layout()
        plt.show()
# Out:
# /var/folders/w1/4h__79_13mng24j5q9dd4k940000gq/T/ipykernel_3879/1831174795.py:9: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_devices['released_date'] = pd.to_datetime(df_devices['released_date'])

# %% [markdown]
# # CONVERTING RAM CAPACITY INTO GB WITH VISUALISATION

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Loading data from the CSV file into a DataFrame
file_name = "device_features.csv"
df_devices = pd.read_csv(file_name)

# Retrieving necessary columns for analysis
ram_capacity_data = df_devices[['model', 'ram_capacity']]

# Drop rows with missing RAM capacity data
ram_capacity_data = ram_capacity_data.dropna(subset=['ram_capacity'])

# Convert RAM capacity to string and then remove 'GB' from the values
ram_capacity_data['ram_capacity'] = ram_capacity_data['ram_capacity'].astype(str).str.replace('GB', '')

# Convert RAM capacity to numeric (float)
ram_capacity_data['ram_capacity'] = ram_capacity_data['ram_capacity'].astype(float)

# Plotting RAM capacity distribution
plt.figure(figsize=(8, 4))
plt.hist(ram_capacity_data['ram_capacity'], bins=15, color='skyblue', edgecolor='black')
plt.title('Distribution of RAM Capacities Across Device Models', fontsize=14)
plt.xlabel('RAM Capacity (GB)', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.show()
